# %% [markdown]
# # 01 Data Audit
#
# Status: template
#
# Purpose: audit row counts, missing fields, and import integrity for `data/processed/ai4s_legitimacy.sqlite3`.
#
# Suggested inputs: local research DB at `data/processed/ai4s_legitimacy.sqlite3` and current freeze checkpoints under `outputs/reports/freeze_checkpoints/`.
#
# Recommended command/module: `python -m ai4s_legitimacy.analysis.reporting` plus ad hoc read-only SQL checks.
#
# Expected outputs or follow-up artifacts: validate counts before refreshing `outputs/reports/freeze_checkpoints/research_db_summary.json`.

# %%
# Template cell: keep this notebook unexecuted by default.
# from pathlib import Path
# db_path = Path("data/processed/ai4s_legitimacy.sqlite3")
