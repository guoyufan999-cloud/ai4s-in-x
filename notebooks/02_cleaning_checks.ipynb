# %% [markdown]
# # 02 Cleaning Checks
#
# Status: template
#
# Purpose: verify normalization, anonymization, and standardization outputs before coding.
#
# Suggested inputs: local research DB, current migration audit context, and a small batch of rows for spot checks.
#
# Recommended command/module: `ai4s-import-legacy` or `python -m ai4s_legitimacy.collection.import_legacy_sqlite` plus targeted read-only SQL validation.
#
# Expected outputs or follow-up artifacts: local adjudication notes and confidence before rerunning migration or coding review.

# %%
# Template cell: keep this notebook unexecuted by default.
# Example spot-check query goes here.
